# %% [markdown]
# <a href="https://colab.research.google.com/github/VikramMadhavSarvagyam/IT609-BigDataProcessing/blob/Assignment1/IT609_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# API request to get the regions of the world from a COVID-19 by regions site.

# %%
import requests
import json
import pandas as pd

url = "https://covid-19-statistics.p.rapidapi.com/regions"

headers = {
	"X-RapidAPI-Key": "aca58c53b8mshbee55354a24b4a7p12b317jsn6490c83fc674",
	"X-RapidAPI-Host": "covid-19-statistics.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# %% [markdown]
# Converting to a dataframe of regions of the world.

# %%
df = pd.json_normalize(response.json()['data'])
df
# Out:
#      iso                 name
# 0    CHN                China
# 1    TWN  Taipei and environs
# 2    USA                   US
# 3    JPN                Japan
# 4    THA             Thailand
# ..   ...                  ...
# 214  KIR             Kiribati
# 215  PLW                Palau
# 216  TON                Tonga
# 217  NRU                Nauru
# 218  TUV               Tuvalu
#
# [219 rows x 2 columns]
